# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib as plt

# %%
adult_df = pd.read_csv('adult.csv')

# %%
adult_df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
adult_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       30725 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      30718 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capitalGain     32561 non-null  int64
#  11  capitalLoss     32561 non-null  int64
#  12  hoursPerWeek    32561 non-null  int64
#  13  nativeCountry   31978 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
adult_df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capitalGain  capitalLoss  hoursPerWeek  nativeCountry income
# 0         2174            0            40  United-States  <=50K
# ...

# %%
adult_df.tail()
# Out:
#        age     workclass  fnlwgt   education  education-num  \
# 32556   27       Private  257302  Assoc-acdm             12
# 32557   40       Private  154374     HS-grad              9
# 32558   58       Private  151910     HS-grad              9
# 32559   22       Private  201490     HS-grad              9
# 32560   52  Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation relationship   race     sex  \
# 32556  Married-civ-spouse       Tech-support         Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 32558             Widowed       Adm-clerical    Unmarried  White  Female
# 32559       Never-married       Adm-clerical    Own-child  White    Male
# 32560  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capitalGain  capitalLoss  hoursPerWeek  nativeCountry income
# 32556            0            0            38  United-States  <=50K
# ...

# %%
adult_df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capitalGain', 'capitalLoss', 'hoursPerWeek', 'nativeCountry',
#        'income'],
#       dtype='object')

# %%
adult_df.shape
# Out:
# (32561, 15)

# %% [markdown]
# ## b)

# %%
adult_df.dropna()
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
adult_df.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capitalGain          0
# capitalLoss          0
# hoursPerWeek         0
# nativeCountry      583
# income               0
# dtype: int64

# %% [markdown]
# ## c)

# %%
adult_df.describe()
# Out:
#                 age        fnlwgt  education-num   capitalGain   capitalLoss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hoursPerWeek
# count  32561.000000
# mean      40.437456
# std       12.347429
# min        1.000000
# 25%       40.000000
# 50%       40.000000
# 75%       45.000000
# max       99.000000

# %%
AgeMean = adult_df["age"].mean
AgeMean
# Out:
# <bound method Series.mean of 0        39
# 1        50
# 2        38
# 3        53
# 4        28
#          ..
# 32556    27
# 32557    40
# 32558    58
# 32559    22
# 32560    52
# Name: age, Length: 32561, dtype: int64>

# %%
EducationNumMedian = adult_df["education-num"].median
EducationNumMedian
# Out:
# <bound method Series.median of 0        13
# 1        13
# 2         9
# 3         7
# 4        13
#          ..
# 32556    12
# 32557     9
# 32558     9
# 32559     9
# 32560     9
# Name: education-num, Length: 32561, dtype: int64>

# %%
CapitalLossCount = adult_df["capitalLoss"].count
CapitalLossCount
# Out:
# <bound method Series.count of 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32556    0
# 32557    0
# 32558    0
# 32559    0
# 32560    0
# Name: capitalLoss, Length: 32561, dtype: int64>

# %%
AgeStd = adult_df["age"].std
AgeStd
# Out:
# <bound method Series.std of 0        39
# 1        50
# 2        38
# 3        53
# 4        28
#          ..
# 32556    27
# 32557    40
# 32558    58
# 32559    22
# 32560    52
# Name: age, Length: 32561, dtype: int64>

# %%
AgeMode = adult_df["age"].mode
AgeMode
# Out:
# <bound method Series.mode of 0        39
# 1        50
# 2        38
# 3        53
# 4        28
#          ..
# 32556    27
# 32557    40
# 32558    58
# 32559    22
# 32560    52
# Name: age, Length: 32561, dtype: int64>

# %%
CapitalLossMax = adult_df["capitalLoss"].max
CapitalLossMax
# Out:
# <bound method Series.max of 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32556    0
# 32557    0
# 32558    0
# 32559    0
# 32560    0
# Name: capitalLoss, Length: 32561, dtype: int64>

# %%
HoursPerWeekMin = adult_df["hoursPerWeek"].min
HoursPerWeekMin
# Out:
# <bound method Series.min of 0        40
# 1        13
# 2        40
# 3        40
# 4        40
#          ..
# 32556    38
# 32557    40
# 32558    40
# 32559    20
# 32560    40
# Name: hoursPerWeek, Length: 32561, dtype: int64>

# %% [markdown]
# ## d)

# %%
adult_df.query('age > 89')
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 222     90           Private   51744       HS-grad              9
# 1040    90           Private  137018       HS-grad              9
# 1935    90           Private  221832     Bachelors             13
# 2303    90           Private   52386  Some-college             10
# 2891    90           Private  171956  Some-college             10
# 4070    90           Private  313986          11th              7
# 4109    90               NaN  256514     Bachelors             13
# 5104    90           Private   52386  Some-college             10
# 5272    90           Private  141758           9th              5
# 5370    90         Local-gov  227796       Masters             14
# 5406    90           Private   51744       Masters             14
# 6232    90  Self-emp-not-inc  155981     Bachelors             13
# 6624    90           Private  313986          11th              7
# ...

# %% [markdown]
# ## e)

# %%
corr = adult_df[['age' , 'race']]
corr.head()
# Out:
#    age   race
# 0   39  White
# 1   50  White
# 2   38  White
# 3   53  Black
# 4   28  Black

# %%
adult_df.plot(kind='scatter', x='age', y='race',title='scatter graph for age and race')
# Out:
# <Axes: title={'center': 'scatter graph for age and race'}, xlabel='age', ylabel='race'>

# %%
adult_df['age'].plot(kind='hist' , title='Age')
# Out:
# <Axes: title={'center': 'Age'}, ylabel='Frequency'>

# %%
adult_df['age'].plot(kind='box' , title= 'Abox plot to show the Age')
# Out:
# <Axes: title={'center': 'Abox plot to show the Age'}>

# %%
adult_df.boxplot(column = 'age' , by = 'capitalGain')
# Out:
# <Axes: title={'center': 'age'}, xlabel='capitalGain'>
